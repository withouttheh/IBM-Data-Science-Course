# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Luto Sibotoboto**
# Junior Data Scientist

# %% [markdown]
# *I am interested in data science because I want to use data to drive decision-making and improve quality assurance practices in the construction industry.*

# %% [markdown]
# ### The code in Cell 5 is function that returns the square of the number passed to it.

# %%
def square(x):
    return x*x
    
square(5)
# Out:
# 25

# %% [markdown]
# 1. First Item
# 2. Second Item
# 3. Third Item
#
# - First Item
# - Second Item
# - Third Item
#
#
# My favourite learning platform is [Coursera](coursera.org)
